# %%
import pandas as pd
import networkx as nx
import numpy as np
import nltk.metrics as nm
import editdistance

# %%
# Load NBER Graph from File

path = '../save/nber.graphml'
G = nx.read_graphml(path)

# %%
# We can generate subgraphs this way
def getJELSubgraph(G, jelcode):
    SG = nx.Graph()
    sge = [e for e in G.edges(data=True) if jelcode in e[2]['jelcode']]
    SG.add_edges_from(sge)
    return SG

# %%
# Returns the Mean all-pairs node connectivity of a JEL Code
def getConnEst(G, jelcode):
    return np.mean(nx.all_pairs_node_connectivity(getJELSubgraph(G, jelcode)).values()[0].values())

# %%
# Get List of JEL codes
e = G.edges(data=True)
jels = set(','.join([x[2]['jelcode'] for x in e]).split(','))

# Get List of Nodes
n = G.nodes()
ndf = pd.DataFrame(n, columns=['author'])

# %%
## Merge in Departments
department = pd.read_csv('../../../work_erica/EconIdeaNetwork/save/REPEC_Paper_Info.csv', delimiter=',')
department = department.drop_duplicates()

# %%
department['authorClean'] = department.Author.apply(lambda x: x.replace(',','').split(' '))
department['authorClean'] = department['authorClean'].apply(lambda x: x[1] + x[0])

# %%
# HACK: Drop duplicates by taking first institution 
department = department.groupby('authorClean').first().reset_index()

# %%
# Manually Check for matches using Levenstein Distance (tolerance = 2)

authorDF = []

def getAuthorMatches(author):

    matches = pd.DataFrame(ndf.author[ndf.author.apply(lambda x: editdistance.eval(x, author)) < 2])
    matches['repecAuthor'] = author

    return matches

# %%
# %%time
# Get list of Author Matches
deptMatches = department.authorClean.apply(getAuthorMatches)
deptMatches = pd.concat(list(deptMatches))
# Out:
# CPU times: user 1min 27s, sys: 468 ms, total: 1min 28s
# Wall time: 1min 29s

# %%
s = deptMatches.groupby('repecAuthor').size()
nberAuthorErrors = s[s > 1].index

# Fix Author Errors in NBER by merging
# Nodes with wrong names

for currAuthor in nberAuthorErrors:

    prevAuthorNames = deptMatches[deptMatches.repecAuthor == currAuthor].author.values

    # For each prev name, collect all edges
    # then delete node

    allPrevEdges = []

    for prevName in prevAuthorNames:

        prevEdges = G.edges(prevName)
        prevEdges = [x[1] for x in prevEdges]
        allPrevEdges = allPrevEdges + prevEdges

        G.remove_node(prevName)

    # Create new node with full set of edges

    for target in allPrevEdges:
        G.add_edge(prevAuthorNames[0], target)

# %%
# Merge Department Affiliations onto Author Matches
authDept = pd.merge(deptMatches, department, how='left', left_on='repecAuthor', right_on='authorClean')

# %%
# Get list of NBER authors corresponding to Institution

instGraphs = {}
insts = department.Institution.unique()

for currInst in insts:
    instGraphs[currInst] = G.subgraph(list(authDept[authDept.Institution == currInst].author))
    nx.write_graphml(instGraphs[currInst], \
                     '../save/' + currInst.replace(',','').replace(' ','_') + '.graphml')

# %%
# Summarize Institutional Graphs

instDf = pd.DataFrame()
instDf['Institution'] = insts
instDf['Graph'] = instDf.Institution.apply(lambda x: instGraphs[x])
# Avg Degree, Avg Centrality, Number of COmponents, Number of Nodes, 
# Longest Shortest Path, Total # of Papers, Avg # of Papers, % of Papers within Dept
# Rank

instDf['AvgDegree'] = instDf.Graph.apply(lambda x: \
                                         np.mean(nx.degree(x, x.nodes()).values()))
instDf['nNodes'] = instDf.Graph.apply(lambda x: len(x.nodes()))

# Drop Empty Departments
instDf = instDf[instDf.nNodes != 0]

instDf['nCC'] = instDf.Graph.apply(lambda x: \
                                   len([c for c in nx.connected_components(x)]))
instDf['AvgSizeCC'] = instDf.Graph.apply(lambda x: \
                                         np.mean([len(c) for c in nx.connected_components(x)]))
instDf['MaxSizeCC'] = instDf.Graph.apply(lambda x: \
                                         np.max([len(c) for c in nx.connected_components(x)]))

# %%
NBERPapers = pd.read_csv('../save/NBER_Paper_Info.csv', delimiter='|')
# Out:
#        Unnamed: 0                                              title  \
# 0               0    ". . . and six hundred thousand men were dead."
# 1               1     "Aggregation Bias" DOES Explain the PPP Puzzle
# 2               2  "Basket" Cases: International Joint Ventures A...
# 3               3              "Beauty Is the Promise of Happiness"?
# 4               4  "Conditional scholarships" for HIV/AIDS Health...
# 5               5         "Convergence in the Age of Mass Migration"
# 6               6            "Currency Manipulation" and World Trade
# 7               7  "Do the Right Thing:" The Effects of Moral Sua...
# 8               8  "Excess Volatility" and the German Stock Marke...
# 9               9                       "Fifty-four Forty or Fight!"
# 10             10  "Getting the Biggest Bang for the Buck in Fisc...
# 11             11     "Hall of Fame" Voting: The Econometric Society
# 12             12  "Healthy, Wealthy and Wise?" Revisited: An Ana...
# 13             13  "Household Responses for Pricing Garbage by th...
# 14             14  "Last-place Aversion": Evidence and Redistribu...
# 15             15                       "Loans for Shares" Revisited
# 16             16  "Lost" on the Web: Does Web Distribution Stimu...
# 17             17  "Make Us a King": Anarchy, Predation, and the ...
# 18             18  "Might Not Be a Tomorrow": A Multi-Methods App...
# 19             19  "Momma's Got the Pill": How Anthony Comstock a...
# 20             20  "Napsterizing" Pharmaceuticals: Access, Innova...
# 21             21  "New" Trade Theory and Policy a Decade Old: As...
# 22             22  "Overreaction" of Asset Prices in General Equi...
# 23             23  "Peso Problem" Explanations for Term Structure...
# 24             24  "Public Sector Pension Governance and Performa...
# 25             25  "Selling Out" and the Impact of Music Piracy o...
# 26             26  "Sick of Local Government Corruption? Vote Isl...
# 27             27  "Social Security Privatization: A Structure fo...
# 28             28  "Sticker Shock" in Individual Insurance under ...
# 29             29  "Success Taxes," Entrepreneurial Entry, and In...
# ...           ...                                                ...
# 17358       17358  Would the Elimination of Affirmative Action Af...
# 17359       17359             Wrongful Discharge Laws and Innovation
# 17360       17360  X-CAPM: An Extrapolative Capital Asset Pricing...
# 17361       17361  Y2K and Offshoring: The Role of External Econo...
# 17362       17362  Yesterday's Heroes: Compensation and Creative ...
# 17363       17363  Yet Another Tale of Two Cities: Buenos Aires a...
# 17364       17364  You Can't Take It With You? Immigrant Assimila...
# 17365       17365  You Cannot be Serious: The Conceptual Innovato...
# 17366       17366  You Get What You Pay For: Schooling Incentives...
# 17367       17367  You Get a Book! Demand Spillovers, Combative A...
# 17368       17368  You Only Die Once: Managing Discrete Interdepe...
# 17369       17369                                         You Owe Me
# 17370       17370  You've Earned It: Combining Field and Lab Expe...
# 17371       17371  Young and Out in Germany: On the Youths' Chanc...
# 17372       17372  Young, Restless and Creative: Openness to Disr...
# 17373       17373                Youth Alcohol Use and Public Policy
# 17374       17374      Youth Depression and Future Criminal Behavior
# 17375       17375  Youth Labor Markets in the U.S.: Shopping Arou...
# 17376       17376  Youth Smoking in the U.S.: Evidence and Implic...
# 17377       17377     Youth Smoking in the U.S.: Prices and Policies
# 17378       17378  Youth Smoking, Cigarette Prices, and Anti-Smok...
# 17379       17379  Youths at Nutritional Risk: Malnourished or Mi...
# 17380       17380  Zero Returns to Compulsory Schooling In German...
# 17381       17381  Zeros, Quality and Space: Trade Theory and Tra...
# 17382       17382  Zombie Lending and Depressed Restructuring in ...
# 17383       17383  Zoning and the Political Economy of Local Redi...
# 17384       17384  Zvi Griliches' Contribution to the Theory of H...
# 17385       17385  band Labor Demand: Evidence from the South Coa...
# 17386       17386  To Have and Have Not: Are Rich Litigious Plain...
# 17387       17387  Nash-in-Nash Bargaining: A Microfoundation for...
#
#                                                  authors  \
# 0                                   Herschel I. Grossman
# 1      Jean Imbs, Haroon Mumtaz, Morten O. Ravn, Hlne...
# 2                    Mihir A. Desai, James R. Hines, Jr.
# 3                    Daniel S. Hamermesh, Jason Abrevaya
# 4                       Till Brnighausen, David E. Bloom
# 5                  Alan M. Taylor, Jeffrey G. Williamson
# 6                       Robert W. Staiger, Alan O. Sykes
# 7                             Ernesto Dal B, Pedro Dal B
# 8                       J. Bradford De Long, Marco Becht
# 9                                   Herschel I. Grossman
# 10                                      Miles S. Kimball
# 11                    Daniel S. Hamermesh, Peter Schmidt
# 12     Till Stowasser, Florian Heiss, Daniel McFadden...
# 13                     Don Fullerton, Thomas C. Kinnaman
# 14     Ilyana Kuziemko, Ryan W. Buell, Taly Reich, Mi...
# 15                                       Daniel Treisman
# 16                                        Joel Waldfogel
# 17                                  Herschel I. Grossman
# 18          Timothy Brezina, Erdal Tekin, Volkan Topalli
# 19                                      Martha J. Bailey
# 20     James W. Hughes, Michael J. Moore, Edward A. S...
# 21                                   J. David Richardson
# 22                         S. Rao Aiyagari, Mark Gertler
# 23     Geert Bekaert, Robert J. Hodrick, David A. Mar...
# 24                    Olivia S. Mitchell, Ping Lung Hsin
# 25                                        Joshua S. Gans
# 26                      J. Vernon Henderson, Ari Kuncoro
# 27                 Olivia S. Mitchell, Stephen P. Zeldes
# 28              Mark Pauly, Scott Harrington, Adam Leive
# 29                   William M. Gentry, R. Glenn Hubbard
# ...                                                  ...
# 17358                        David Card, Alan B. Krueger
# 17359  Viral V. Acharya, Ramin P. Baghai, Krishnamurt...
# 17360  Nicholas Barberis, Robin Greenwood, Lawrence J...
# 17361                      Devashish Mitra, Priya Ranjan
# 17362   Ing-Haw Cheng, Harrison Hong, Jose A. Scheinkman
# 17363                 Filipe Campante, Edward L. Glaeser
# 17364                                Rachel M. Friedberg
# 17365                                     David Galenson
# 17366                Eric V. Edmonds, Maheshwor Shrestha
# 17367                                Craig L. Garthwaite
# 17368                   Geoffrey Heal, Howard Kunreuther
# 17369                   Ulrike Malmendier, Klaus Schmidt
# 17370    Pamela Jakiela, Edward Miguel, Vera L. te Velde
# 17371  Wolfgang Franz, Joachim Inkmann, Winfried Pohl...
# 17372      Daron Acemoglu, Ufuk Akcigit, Murat Alp Celik
# 17373                 Adit Laixuthai, Frank J. Chaloupka
# 17374         D. Mark Anderson, Resul Cesur, Erdal Tekin
# 17375                                      David Neumark
# 17376                   Jonathan Gruber, Jonathan Zinman
# 17377                                    Jonathan Gruber
# 17378  Philip DeCicca, Donald S. Kenkel, Alan D. Math...
# 17379                     Jay Bhattacharya, Janet Currie
# 17380             Jorn-Steffen Pischke, Till von Wachter
# 17381                    Richard Baldwin, James Harrigan
# 17382  Ricardo J. Caballero, Takeo Hoshi, Anil K. Kas...
# 17383                 Raquel Fernandez, Richard Rogerson
# 17384                                      Reuben Gronau
# 17385                           Eli Berman, Linda T. Bui
# 17386                                     B. Zorina Khan
# 17387  Allan Collard-Wexler, Gautam Gowrisankaran, Ro...
#
#                               jel
# 0                              D7
# 1                      C2, F1, F3
# 2                          F2, H8
# 3                      C2, I3, J1
# 4                      I1, I2, J2
# 5                          F2, N1
# 6                  F0, F1, F3, K3
# 7                          C9, H4
# 8                              N2
# 9                              D7
# 10                             E6
# 11                         A1, D7
# 12     C3, C5, I0, I1, I3, J0, J2
# 13                         D6, H2
# 14         C9, D3, D7, H2, I3, J3
# 15                     H8, P2, P3
# 16                         L1, L8
# 17                         D6, D7
# 18                         K0, K4
# 19                     I1, J0, J1
# 20                             O3
# 21                             F0
# 22                         E0, G1
# 23                         F3, G1
# 24                         B0, J3
# 25                     D0, K1, L8
# 26                 H7, O1, P1, R5
# 27                         E6, H5
# 28                             I1
# 29                         H0, O0
# ...                           ...
# 17358                      I2, J7
# 17359                  G3, J5, K3
# 17360                      G0, G1
# 17361                          F1
# 17362                  G0, G2, G3
# 17363                  D0, N0, R0
# 17364                      J2, J6
# 17365                          J0
# 17366                      J2, O1
# 17367      D2, I2, L0, L1, L2, L8
# 17368                      C7, D8
# 17369              C9, D6, D7, I1
# 17370                  C9, I2, O1
# 17371                      C2, J2
# 17372              O3, O4, P1, Z1
# 17373                          I1
# 17374                      I1, K4
# 17375                      J3, J6
# 17376                      H2, I1
# 17377                      H2, I1
# 17378                          I1
# 17379                      H5, I1
# 17380                  I2, J2, J3
# 17381                          F1
# 17382              E4, G3, L1, O5
# 17383                      H2, H7
# 17384                      B3, C4
# 17385                      C2, C8
# 17386              K1, K4, N1, O4
# 17387                  C7, D4, L1
#
# [17388 rows x 4 columns]
